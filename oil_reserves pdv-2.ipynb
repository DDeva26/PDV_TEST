# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('oil_reserves.csv')
print(df)
# Out:
#                 Region              Country/ Region     2010     2011  \
# 0        North America                           US   34.990   39.775
# 1        North America                       Canada  174.848  174.177
# 2        North America                       Mexico   11.691   11.394
# 3   S. & Cent. America                    Argentina    2.524    2.525
# 4   S. & Cent. America                       Brazil   14.246   15.050
# 5   S. & Cent. America                     Colombia    1.900    1.988
# 6   S. & Cent. America                      Ecuador    6.158    7.210
# 7   S. & Cent. America                         Peru    1.240    1.206
# 8   S. & Cent. America            Trinidad & Tobago    0.830    0.830
# 9   S. & Cent. America                    Venezuela  296.501  297.571
# 10  S. & Cent. America     Other S. & Cent. America    0.768    0.507
# 11    Europe & Eurasia                   Azerbaijan    7.000    7.000
# ...

# %%
df.max()
print(df)
# Out:
#                 Region              Country/ Region     2010     2011  \
# 0        North America                           US   34.990   39.775
# 1        North America                       Canada  174.848  174.177
# 2        North America                       Mexico   11.691   11.394
# 3   S. & Cent. America                    Argentina    2.524    2.525
# 4   S. & Cent. America                       Brazil   14.246   15.050
# 5   S. & Cent. America                     Colombia    1.900    1.988
# 6   S. & Cent. America                      Ecuador    6.158    7.210
# 7   S. & Cent. America                         Peru    1.240    1.206
# 8   S. & Cent. America            Trinidad & Tobago    0.830    0.830
# 9   S. & Cent. America                    Venezuela  296.501  297.571
# 10  S. & Cent. America     Other S. & Cent. America    0.768    0.507
# 11    Europe & Eurasia                   Azerbaijan    7.000    7.000
# ...

# %%
df.head()
print(df)
# Out:
#                 Region              Country/ Region     2010     2011  \
# 0        North America                           US   34.990   39.775
# 1        North America                       Canada  174.848  174.177
# 2        North America                       Mexico   11.691   11.394
# 3   S. & Cent. America                    Argentina    2.524    2.525
# 4   S. & Cent. America                       Brazil   14.246   15.050
# 5   S. & Cent. America                     Colombia    1.900    1.988
# 6   S. & Cent. America                      Ecuador    6.158    7.210
# 7   S. & Cent. America                         Peru    1.240    1.206
# 8   S. & Cent. America            Trinidad & Tobago    0.830    0.830
# 9   S. & Cent. America                    Venezuela  296.501  297.571
# 10  S. & Cent. America     Other S. & Cent. America    0.768    0.507
# 11    Europe & Eurasia                   Azerbaijan    7.000    7.000
# ...

# %%
print(df[df['2014']==df['2014'].max()]['Region'])
# Out:
# 9    S. & Cent. America
# Name: Region, dtype: object

# %%
print(df[df['2015']==df['2015'].max()]['Region'])
# Out:
# 9    S. & Cent. America
# Name: Region, dtype: object

# %%
#1
sum=df["2014"]+df["2015"]+df["2016"]
print(sum.max())
a=np.where(sum==sum.max())
new=df.iloc[a]
new["Country/ Region"]
# Out:
# 901.809
# 9    Venezuela
# Name: Country/ Region, dtype: object

# %%
#2
df["oil_allyear"]=df["2014"]+df["2015"]+df["2016"]+df["2012"]+df["2013"]+df["2010"]+df["2011"]
df[df["oil_allyear"].max() and df["Region"]=="North America"]
# Out:
#           Region Country/ Region     2010     2011     2012     2013     2014  \
# 0  North America              US   34.990   39.775   44.180   48.463   54.962
# 1  North America          Canada  174.848  174.177  173.716  173.038  172.156
# 2  North America          Mexico   11.691   11.394   11.424   11.079   10.816
#
#       2015     2016  max2014  max2014_2015_2016  oil_allyear
# 0   47.987   47.987  150.936            150.936      318.344
# 1  171.512  171.512  515.180            515.180     1210.959
# 2    7.977    7.977   26.770             26.770       72.358

# %%
#5
print(df.sort_values('2015',ascending=False)["Country/ Region"].head())
# Out:
# 9        Venezuela
# 27    Saudi Arabia
# 1           Canada
# 22            Iran
# 23            Iraq
# Name: Country/ Region, dtype: object

# %%
#6
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('oil_reserves.csv')
plt.barh(df['Region'], df['2014'])
plt.barh(df['Region'], df['2015'])
plt.barh(df['Region'], df['2016'])
plt.xlabel("Year")
plt.ylabel("Region")
plt.legend()
plt.title("oil reserves")
plt.show()

# %%
import matplotlib.pyplot as plt
 
labels = df['Region'].unique()
sizes = [tot_reg1, tot_reg2, tot_reg3, tot_reg4, tot_reg5, tot_reg6]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red', 'silver']
explode = (0, 0, 0, 0.1, 0, 0)
patches, texts = plt.pie(sizes, explode, colors=colors, shadow=True, startangle=30)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-42035173c62e> in <module>()
#       2
#       3 labels = df['Region'].unique()
# ----> 4 sizes = [tot_reg1, tot_reg2, tot_reg3, tot_reg4, tot_reg5, tot_reg6]
#       5 colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red', 'silver']
#       6 explode = (0, 0, 0, 0.1, 0, 0)
#
# NameError: name 'tot_reg1' is not defined
